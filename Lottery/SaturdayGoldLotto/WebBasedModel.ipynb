# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_excel('/Users/sabinhashmi/Code Hub/CodeScripts/Saturday Gold Lotto/ArrangedPredictions.xlsx')
raw_data=pd.read_excel('/Users/sabinhashmi/Code Hub/CodeScripts/Saturday Gold Lotto/Original_LottoWebsitePredictions.xlsx').drop('Number',axis=1)

# %%
data.head(5)
# Out:
#    Number  Wisdom of Crowd  Advanced Prediction  User_Edward  User_Yerpp  \
# 0       1              1.0                  1.0          NaN         1.0
# 1       2              NaN                  2.0          2.0         2.0
# 2       3              3.0                  3.0          3.0         NaN
# 3       4              NaN                  4.0          4.0         4.0
# 4       5              5.0                  NaN          5.0         NaN
#
#    User_AlphaFish  User_j33t  User_Dolph  Algo_Bayessian  Algo_NeuralNetwork
# 0             NaN        1.0         1.0             1.0                 NaN
# 1             NaN        2.0         NaN             NaN                 2.0
# 2             3.0        NaN         NaN             3.0                 NaN
# 3             NaN        4.0         4.0             4.0                 4.0
# 4             5.0        NaN         NaN             5.0                 5.0

# %%
data.shape
# Out:
# (45, 10)

# %%
#Ending last numbers can be removed.
data.count(axis=1).sort_values(ascending=False)
# Out:
# 6     8
# 31    8
# 3     8
# 0     7
# 15    7
# 7     7
# 11    7
# 21    7
# 42    6
# 10    6
# 1     6
# 37    6
# 35    6
# 4     6
# 2     6
# 18    6
# 23    6
# 41    5
# 39    5
# 38    5
# 32    5
# 25    5
# 22    5
# 44    5
# 19    5
# 8     5
# 13    5
# 14    5
# 16    5
# 24    4
# 43    4
# 9     4
# 36    4
# 20    4
# 28    4
# 34    4
# 33    3
# 17    3
# 30    3
# 40    3
# 27    3
# 5     3
# 26    3
# 29    2
# 12    2
# dtype: int64

# %%
raw_data.head()
# Out:
#    Wisdom of Crowd  Advanced Prediction  User_Edward  User_Yerpp  \
# 0               19                   18           21          22
# 1               41                   22            2           2
# 2               25                    1            5          20
# 3               33                   40           19           1
# 4               29                   24           45           7
#
#    User_AlphaFish  User_j33t  User_Dolph  Algo_Bayessian  Algo_NeuralNetwork
# 0               5         38          15              18                   2
# 1              20          1          17              22                   4
# 2              38         40          22               1                   5
# 3              28         14          27               5                   8
# 4              12          2          37              40                  11

# %%
set_1=raw_data.iloc[0:6,:]
set_2=raw_data.iloc[6:12,:]
set_3=raw_data.iloc[12:18,:]
set_4=raw_data.iloc[18:,:]

# %%
set_1
# Out:
#    Wisdom of Crowd  Advanced Prediction  User_Edward  User_Yerpp  \
# 0               19                   18           21          22
# 1               41                   22            2           2
# 2               25                    1            5          20
# 3               33                   40           19           1
# 4               29                   24           45           7
# 5               23                    2           11          45
#
#    User_AlphaFish  User_j33t  User_Dolph  Algo_Bayessian  Algo_NeuralNetwork
# 0               5         38          15              18                   2
# 1              20          1          17              22                   4
# 2              38         40          22               1                   5
# 3              28         14          27               5                   8
# 4              12          2          37              40                  11
# ...

# %%
set_1.sum(axis=0).sort_values()
# Out:
# Algo_NeuralNetwork      44
# User_Yerpp              97
# User_Edward            103
# Advanced Prediction    107
# Algo_Bayessian         110
# User_j33t              112
# User_AlphaFish         147
# User_Dolph             158
# Wisdom of Crowd        170
# dtype: int64

# %%
set_2.sum(axis=0).sort_values()
# Out:
# User_j33t               69
# Advanced Prediction    119
# Algo_Bayessian         119
# User_Yerpp             137
# User_AlphaFish         144
# User_Dolph             166
# Wisdom of Crowd        170
# Algo_NeuralNetwork     177
# User_Edward            193
# dtype: int64

# %%
set_3.sum(axis=0).sort_values()
# Out:
# Wisdom of Crowd         56
# User_Edward             86
# Advanced Prediction    108
# User_Dolph             123
# Algo_Bayessian         126
# User_AlphaFish         132
# Algo_NeuralNetwork     162
# User_Yerpp             178
# User_j33t              180
# dtype: int64

# %%
set_4.sum(axis=0).sort_values()
# Out:
# Algo_NeuralNetwork      20
# User_Dolph              67
# Advanced Prediction     68
# Algo_Bayessian          68
# User_Edward             78
# User_Yerpp              84
# Wisdom of Crowd        100
# User_AlphaFish         114
# User_j33t              124
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
plt.plot(set_1.sum(axis=0).sort_values())
plt.plot(set_2.sum(axis=0).sort_values())
plt.plot(set_3.sum(axis=0).sort_values())
plt.plot(set_4.sum(axis=0).sort_values())




plt.show()
