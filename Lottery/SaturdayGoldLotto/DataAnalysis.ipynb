# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
sns.set_theme(style="darkgrid")

import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel('/Users/sabinhashmi/Code Hub/CodeScripts/Saturday Gold Lotto/Data.xlsx')
data.drop(['Date','From Last','Odd','Even'],axis=1,inplace=True)
print(f"Data Dimension is {data.shape}")
# Out:
# Data Dimension is (689, 6)

# %%
data['Sum']=data.sum(axis=1)

# %%
data.head()
# Out:
#     1   2   3   4   5   6  Sum
# 0  15  17  22  27  37  40  158
# 1  11  16  26  32  39  42  166
# 2   4   6  24  35  42  45  156
# 3   3   5   9  26  35  41  119
# 4   1   3   4  22  42  43  115

# %%
data.Sum.max()
# Out:
# 223

# %%
data['Sum'].value_counts()
# Out:
# 144    16
# 130    15
# 136    13
# 115    12
# 125    12
#        ..
# 78      1
# 69      1
# 66      1
# 62      1
# 223     1
# Name: Sum, Length: 138, dtype: int64

# %%
data['Sum'].describe()
# Out:
# count    689.000000
# mean     137.837446
# std       29.982403
# min       46.000000
# 25%      117.000000
# 50%      136.000000
# 75%      158.000000
# max      223.000000
# Name: Sum, dtype: float64

# %%
sns.boxplot(data['Sum'])
# Out:
# <AxesSubplot:xlabel='Sum'>

# %%
data.head(15)
# Out:
#      1   2   3   4   5   6  Sum
# 0   15  17  22  27  37  40  158
# 1   11  16  26  32  39  42  166
# 2    4   6  24  35  42  45  156
# 3    3   5   9  26  35  41  119
# 4    1   3   4  22  42  43  115
# 5    3   6   8  10  12  24   63
# 6    3   6  15  20  30  31  105
# 7    1   6   8  10  29  40   94
# 8    4  12  14  17  22  33  102
# 9    7   9  20  22  34  45  137
# 10   5   7  14  16  17  44  103
# 11   2   5  11  21  30  32  101
# 12   9  16  26  35  39  41  166
# 13  14  16  35  38  40  43  186
# 14   1   9  11  24  32  41  118

# %%
for i in range(1,7):
    sns.countplot(data[i],order=data[i].value_counts().head(10).index)
    plt.show()

# %%
#Most_Occuring Numbers
for i in range(1,7):
    list_01=list(data[i].value_counts().head(10).index)
    print(list_01)
# Out:
# [1, 3, 4, 2, 5, 6, 7, 8, 9, 11]
# [10, 11, 9, 12, 13, 6, 8, 5, 7, 19]
# [18, 16, 20, 13, 15, 22, 24, 21, 14, 17]
# [29, 26, 24, 27, 32, 30, 33, 22, 25, 23]
# [39, 38, 37, 32, 40, 31, 42, 36, 41, 34]
# [45, 43, 44, 42, 41, 40, 38, 39, 34, 37]

# %%
repeating_sequence=[]
for i in range(6):
    repeating_sequence.append(int(input(f'Enter {i+1} Value')))

print(repeating_sequence)
# Out:
# [1, 2, 3, 4, 3, 1]
