# %%
import pandas as pd

# %%
data=pd.read_csv('/Users/sabinhashmi/Code Hub/CodeScripts/Saturday Gold Lotto/PredictedSequence.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Number-1  Number-2  Number-3  Number-4  Number-5  Number-6  Sum
# 0           0         4         7        15        24        40        43  133
# 1         936         5        11        22        24        32        40  134
# 2        1711         4        11        20        22        32        45  134
# 3        1898         2         7        14        32        38        39  132
# 4        1973         9        19        24        26        40        45  163

# %%
data.shape
# Out:
# (241, 8)

# %%
data=data.drop(['Unnamed: 0','Sum'],axis=1)

# %%
old_sequence=[8,9,13,19,22,32]
print(data[data.isin(old_sequence)==True].dropna(how='any'))
# Out:
# Empty DataFrame
# Columns: [Number-1, Number-2, Number-3, Number-4, Number-5, Number-6]
# Index: []

# %%
pd.set_option('display.max_rows',1000)
data.sort_values(by=['Number-1', 'Number-2', 'Number-3', 'Number-4', 'Number-5', 'Number-6'])
# Out:
#      Number-1  Number-2  Number-3  Number-4  Number-5  Number-6
# 220         1         5        15        24        39        40
# 125         1         5        15        26        36        42
# 46          1         5        17        26        40        43
# 106         1         5        17        26        42        43
# 67          1         5        20        24        36        42
# 41          1         7        14        26        38        45
# 121         1         7        15        32        36        39
# 26          1         7        16        24        36        39
# 23          1         7        16        32        38        43
# 13          1         8        14        22        32        45
# 233         1         8        17        32        40        42
# 206         1         8        17        33        38        39
# 221         1         8        22        23        32        38
# 96          1         8        22        23        36        42
# ...
